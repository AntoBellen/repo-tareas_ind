# %% [markdown]
# #Problema 1. Clasificador de temperatura
# Crea un programa que imprima los números desde -30 hasta 50.
#
# Para cada número, además de imprimirlo, el programa debe mostrar un texto según estas reglas:
#
# si el número es menor que 0, mostrar "Muy frío"
# si el número está entre 0 y 24, mostrar "Templado"
# si el número es mayor o igual a 25, mostrar "Caluroso"

# %%
#Ejemplo de salida:

#-3 Muy frío
#0 Templado
#18 Templado
#30 Caluroso

# %%
for temperatura in range(-30,51): #incluimos 51 porque "range" no incluye el ultimo numero
  if temperatura<0:
    print(temperatura,"º","Muy frío")
  elif temperatura<25:
    print(temperatura,"º","Templada")
  else:
    print(temperatura,"º","Calurosa")
# Out:
# -30 º Muy frío
# -29 º Muy frío
# -28 º Muy frío
# -27 º Muy frío
# -26 º Muy frío
# -25 º Muy frío
# -24 º Muy frío
# -23 º Muy frío
# -22 º Muy frío
# -21 º Muy frío
# -20 º Muy frío
# -19 º Muy frío
# -18 º Muy frío
# -17 º Muy frío
# -16 º Muy frío
# -15 º Muy frío
# -14 º Muy frío
# -13 º Muy frío
# -12 º Muy frío
# -11 º Muy frío
# -10 º Muy frío
# -9 º Muy frío
# -8 º Muy frío
# -7 º Muy frío
# -6 º Muy frío
# -5 º Muy frío
# -4 º Muy frío
# -3 º Muy frío
# -2 º Muy frío
# -1 º Muy frío
# 0 º Templada
# 1 º Templada
# 2 º Templada
# 3 º Templada
# 4 º Templada
# 5 º Templada
# 6 º Templada
# 7 º Templada
# 8 º Templada
# 9 º Templada
# 10 º Templada
# 11 º Templada
# 12 º Templada
# 13 º Templada
# 14 º Templada
# 15 º Templada
# 16 º Templada
# 17 º Templada
# 18 º Templada
# 19 º Templada
# 20 º Templada
# 21 º Templada
# 22 º Templada
# 23 º Templada
# 24 º Templada
# 25 º Calurosa
# 26 º Calurosa
# 27 º Calurosa
# 28 º Calurosa
# 29 º Calurosa
# 30 º Calurosa
# 31 º Calurosa
# 32 º Calurosa
# 33 º Calurosa
# 34 º Calurosa
# 35 º Calurosa
# 36 º Calurosa
# 37 º Calurosa
# 38 º Calurosa
# 39 º Calurosa
# 40 º Calurosa
# 41 º Calurosa
# 42 º Calurosa
# 43 º Calurosa
# 44 º Calurosa
# 45 º Calurosa
# 46 º Calurosa
# 47 º Calurosa
# 48 º Calurosa
# 49 º Calurosa
# 50 º Calurosa

# %% [markdown]
# #Problema 2. Números especiales del robot
# Crea un programa que imprima los números del 1 al 100 que sean divisibles por 5.
#
# Además, el programa debe cumplir estas condiciones:
#
# si el número es divisible por 5, imprimir el número junto con el texto "Bip" si el número también es divisible por 10, imprimir el número junto con el texto "Bip Bip" Ejemplo de salida

# %%
#5 Bip
#10 Bip Bip
#15 Bip
#20 Bip Bip
#Ayuda
#Recuerda que el operador % permite obtener el resto de una división:
#10 % 5 == 0
#20 % 10 == 0

# %%
for i in range(1,101):
  if i % 10 == 0:
    print(i,"Bip Bip")
  elif i % 5 ==0:
    print(i,"Bip")
# Out:
# 5 Bip
# 10 Bip Bip
# 15 Bip
# 20 Bip Bip
# 25 Bip
# 30 Bip Bip
# 35 Bip
# 40 Bip Bip
# 45 Bip
# 50 Bip Bip
# 55 Bip
# 60 Bip Bip
# 65 Bip
# 70 Bip Bip
# 75 Bip
# 80 Bip Bip
# 85 Bip
# 90 Bip Bip
# 95 Bip
# 100 Bip Bip

# %% [markdown]
# #Problema 3. Detector de puntaje gamer
# Crea un programa que solicite al usuario dos números, los sume y luego muestre un mensaje según el resultado.
#
# Reglas
#
# 1.   si la suma es menor que 50, mostrar "Nivel principiante"
# 2.   si la suma es mayor o igual a 50 y menor que 80, mostrar "Nivel intermedio"
# 3. si la suma es mayor o igual a 80, mostrar "Nivel pro"

# %% [markdown]
# Ejemplo de ejecución
#
# Ingresa primer puntaje: 20
# \
# Ingresa segundo puntaje: 25
# \
# Resultado: Nivel principiante

# %%
puntaje1=int(input("Ingresa el primer puntaje obtenido:"))
puntaje2=int(input("Ingresa el segundo puntaje obtenido:"))
resultado = puntaje1 + puntaje2
if resultado < 50:
    print(f"Tu puntaje es {resultado}. Eres nivel principiante")
elif resultado < 80:
    print(f"Tu puntaje es {resultado}. Eres nivel intermedio")
else:
    print(f"Tu puntaje es {resultado}. Eres nivel Pro")
# Out:
# Ingresa el primer puntaje obtenido:52
# Ingresa el segundo puntaje obtenido:67
# Tu puntaje es 119. Eres nivel Pro

# %% [markdown]
# #Problema 4. Calculador de perfil musical
# Crea un programa que evalúe el perfil del usuario según su edad y sus gustos.
#
#
#
#
# El usuario debe recibir los siguientes parámetros:
# * edad
# * le_gusta_musica
# * le_gusta_bailar
#
#
# Y debe retornar uno de los siguientes mensajes:
# \
# "Eres una estrella de la fiesta" si la persona tiene 18 o más años, le gusta la música y le gusta bailar
# \
# "Te gusta la música, pero no tanto bailar" si le gusta la música pero no le gusta bailar
# \
# "Tienes tu propio estilo" en cualquier otro caso

# %%
edad=int(input("Ingresa tu edad: ")) # int dado que es numero entero
le_gusta_musica=input("Te gusta la musica?: (contesta con si/no) ") # entrega texto (string)
le_gusta_bailar=input("Te gusta bailar?: (contesta con si/no) ")
if edad >= 18 and le_gusta_musica =="si" and le_gusta_bailar=="si":
   print("Eres una estrella de la fiesta")
elif le_gusta_musica=="si" and le_gusta_bailar=="no":
    print("Te gusta la música, pero no tanto bailar")
else:
    print("Tienes tu propio estilo")
# Out:
# Ingresa tu edad: 21
# Te gusta la musica?: (contesta con si/no) si
# Te gusta bailar?: (contesta con si/no) si
# Eres una estrella de la fiesta
